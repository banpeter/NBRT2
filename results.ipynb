# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
dataset_names = ["Blob","iris","wine","house_price"]
#rt - regression tree
#rtl - regression tree linear regresion
#rtln - regression tree linear regresion non binray
#rtn - regression tree non binray
#rtni - regression tree linear regresion non binray incremental
#The meaning of the numbers next to the non binary trees, is the amount of sub_nodes

# %%
#Execution time
'''times = []

with open("Results/research/times_rte_mse_nbrt2.csv","r") as file:

    data = []
    for i in range(4):
        d = [[0] for x in range(15)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count

    times.append(data) 

with open("Results/research/times_push_mse_nbrt2.csv","r") as file:

    data = []
    for i in range(4):
        d = [[0] for x in range(15)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count

    times.append(data) '''
# Out:
# 'times = []\n\nwith open("Results/research/times_rte_mse_nbrt2.csv","r") as file:\n\n    data = []\n    for i in range(4):\n        d = [[0] for x in range(15)]\n        data.append(d)\n    count = 0\n    for row in file:\n        row = row.strip(\'\n\').split(\',\')\n        row = [float(x) for x in row ]\n\n        \n        for i in range(len(row)):\n            data[count][i][0] += row[i] \n            #print(d[i][0],row[i])\n            #d[i][0] += row[i] \n        #print(d)\n        count+=1\n        if(count == 4):\n            count = 0\n\n\n    for i in range(len(data)):\n        for j in range(len(data[0])):\n            data[i][j][0] /=10\n        #d[i][0] = d[i][0]/count\n\n    times.append(data) \n\nwith open("Results/research/times_push_mse_nbrt2.csv","r") as file:\n\n    data = []\n    for i in range(4):\n        d = [[0] for x in range(15)]\n        data.append(d)\n    count = 0\n    for row in file:\n        row = row.strip(\'\n\').split(\',\')\n        row = [float(
# ...

# %%
#Execution time
'''depth = []

with open("Results/research/times_rte_mse_nbrt2.csv","r") as file:

    data = []
    for i in range(4):
        d = [[0] for x in range(15)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count

    depth.append(data) 

with open("Results/research/times_push_mse_nbrt2.csv","r") as file:

    data = []
    for i in range(4):
        d = [[0] for x in range(15)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count

    depth.append(data) '''
# Out:
# 'depth = []\n\nwith open("Results/research/times_rte_mse_nbrt2.csv","r") as file:\n\n    data = []\n    for i in range(4):\n        d = [[0] for x in range(15)]\n        data.append(d)\n    count = 0\n    for row in file:\n        row = row.strip(\'\n\').split(\',\')\n        row = [float(x) for x in row ]\n\n        \n        for i in range(len(row)):\n            data[count][i][0] += row[i] \n            #print(d[i][0],row[i])\n            #d[i][0] += row[i] \n        #print(d)\n        count+=1\n        if(count == 4):\n            count = 0\n\n\n    for i in range(len(data)):\n        for j in range(len(data[0])):\n            data[i][j][0] /=10\n        #d[i][0] = d[i][0]/count\n\n    depth.append(data) \n\nwith open("Results/research/times_push_mse_nbrt2.csv","r") as file:\n\n    data = []\n    for i in range(4):\n        d = [[0] for x in range(15)]\n        data.append(d)\n    count = 0\n    for row in file:\n        row = row.strip(\'\n\').split(\',\')\n        row = [float(
# ...

# %%
#Sum of difference between the test and predicted data
diff = []
limits = [120,115,110,105,100,95,90,85,80,75,70,65,60,55,50,45,40,35,30,25,20,15,10]
with open("/home/peter/Development/NBRT2/Results3/base/difference_push3_mse_nbrt2.csv","r") as file:

    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count

    diff.append(data)  

#with open("Results/research_d/difference_hybrid32_mse_nbrt2.csv","r") as file:
with open("/home/peter/Development/NBRT2/Results3/4/difference_push3_mse_nbrt2.csv","r") as file:
    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count
        print(data[i])

    diff.append(data)   

with open("/home/peter/Development/NBRT2/Results3/5/difference_push3_mse_nbrt2.csv","r") as file:
    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count
        print(data[i])

    diff.append(data)   

    
with open("/home/peter/Development/NBRT2/Results3/hybrid/difference_hybrid_push3_mse_nbrt2.csv","r") as file:
    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count
        print(data[i])

    diff.append(data)   

with open("/home/peter/Development/NBRT2/Results3/rte/difference_rte_ext_mse_nbrt2.csv","r") as file:
    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count
        print(data[i])

    diff.append(data)  


with open("/home/peter/Development/NBRT2/Results3/test5/difference_push3_mse_nbrt2.csv","r") as file:
    data = []
    for i in range(4):
        d = [[0] for x in range(23)]
        data.append(d)
    count = 0
    for row in file:
        row = row.strip('\n').split(',')
        row = [float(x) for x in row ]

        
        
        for i in range(len(row)):
            data[count][i][0] += row[i] 
            #print(d[i][0],row[i])
            #d[i][0] += row[i] 
        #print(d)
        count+=1
        if(count == 4):
            count = 0


    for i in range(len(data)):
        for j in range(len(data[0])):
            data[i][j][0] /=10
        #d[i][0] = d[i][0]/count
        if(i == 0):
            print(data[i])

    diff.append(data)  

print(len(diff))
print(diff[0])
#print(diff[1])
# Out:
# [[0.02775977526610477], [0.027780150542547295], [0.027816755255393837], [0.027859386476300325], [0.02792077970914255], [0.027989530937329993], [0.028058645779326864], [0.02814070462721942], [0.028198532607623783], [0.028296609491003755], [0.028446207283666303], [0.02858023787084512], [0.028767238520960803], [0.029018812590285513], [0.029299427220722374], [0.02971396394863545], [0.03010909745276592], [0.03075051374539873], [0.031591649919160594], [0.032741921390570264], [0.0344720317217703], [0.037025889833078536], [0.04073111493226099]]
# ...

# %%
'''x = [1,2,3,4,5]
y = [2,1,3,6,7]

plt.plot(x, y, "-o")
x0 = [2]
y0 = [1]
plt.plot(x0, y0, "s")

plt.show()'''
# Out:
# 'x = [1,2,3,4,5]\ny = [2,1,3,6,7]\n\nplt.plot(x, y, "-o")\nx0 = [2]\ny0 = [1]\nplt.plot(x0, y0, "s")\n\nplt.show()'

# %%
'''# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

# Plotting
plt.plot(x, y)


plt.gca().invert_xaxis()

# Get the current axis
#ax = plt.gca()

# Set the x-axis inversion to False
#ax.invert_xaxis(False)

# Show the plot
plt.show()'''
# Out:
# '# Sample data\nx = [1, 2, 3, 4, 5]\ny = [10, 20, 25, 30, 35]\n\n# Plotting\nplt.plot(x, y)\n\n\nplt.gca().invert_xaxis()\n\n# Get the current axis\n#ax = plt.gca()\n\n# Set the x-axis inversion to False\n#ax.invert_xaxis(False)\n\n# Show the plot\nplt.show()'

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['font.size'] = 20
#print(data[1])
data = []
print(diff[0])

for i in diff:
        print(i[0])
        data.append(i[0])
print(data[0])
#print(data[1])

limits = [120,115,110,105,100,95,90,85,80,75,70,65,60,55,50,45,40,35,30,25,20,15,10]

a = [x[0] for x in data[0]]
b = [x[0] for x in data[1]]
c = [x[0] for x in data[2]]
d = [x[0] for x in data[3]]
e = [x[0] for x in data[4]]
f = [x[0] for x in data[5]]

#print(a[::-1])

plt.plot(limits, a, "-o", label="divide 3")
#plt.gca().invert_xaxis()
plt.plot(limits, b, "-o", label="divide 4")
#plt.gca().invert_xaxis()
plt.plot(limits, c, "-o", label="divide 5")
#plt.gca().invert_xaxis()
plt.plot(limits, d, "-o", label="hybrid (div 3)")

plt.plot(limits, e, "-o", label="Base Line")

plt.plot(limits, f, "-o", label="opt")
#plt.gca().invert_xaxis()
#plt.xlim(max(limits),min(limits))
plt.legend()
#plt.gca().invert_yaxis()
#plt.savefig('Results3/plots/windmill_error.png') 
plt.show()
# Out:
# [[[0.027701210876738786], [0.027728238998287923], [0.027739669272737195], [0.027792703726398676], [0.027857459621856866], [0.02790618266624829], [0.027931257349779127], [0.027995807832953253], [0.02804758723542201], [0.02815777211118804], [0.02826235572101247], [0.028358948209339464], [0.028515938043767914], [0.028686450616014096], [0.028927655273825813], [0.029231043825706283], [0.029671337050852908], [0.030261192306589246], [0.031002210821041508], [0.0321998848885859], [0.033663117061374974], [0.03587411881021146], [0.03946515686626961]], [[0.2476943167620851], [0.24310798431390873], [0.23857291617590587], [0.23846118649752013], [0.23677247472730115], [0.23677247472730115], [0.2362080436633501], [0.23443272834961246], [0.21644480984164222], [0.22830863095589932], [0.22853578534525815], [0.22847753721738231], [0.2281981284065354], [0.22631779960928694], [0.22699324852630665], [0.22608914155291684], [0.21666580773809763], [0.21100160113743943], [0.2055354521539336], [0.19437090107751
# ...

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['font.size'] = 20
print(data[1])
data = []
print(diff[0])

for i in diff:
        data.append(i[1])
print(data[0])
print(data[1])

limits = [120,115,110,105,100,95,90,85,80,75,70,65,60,55,50,45,40,35,30,25,20,15,10]
a = [x[0] for x in data[0]]
b = [x[0] for x in data[1]]
c = [x[0] for x in data[2]]
d = [x[0] for x in data[3]]
e = [x[0] for x in data[4]]
f = [x[0] for x in data[5]]

#print(a[::-1])

plt.plot(limits, a, "-o", label="divide 3")
#plt.gca().invert_xaxis()
plt.plot(limits, b, "-o", label="divide 4")
#plt.gca().invert_xaxis()
plt.plot(limits, c, "-o", label="divide 5")
#plt.gca().invert_xaxis()
plt.plot(limits, d, "-o", label="hybrid (div 3)")

plt.plot(limits, e, "-o", label="Base Line")

plt.plot(limits, f, "-o", label="opt")
#plt.gca().invert_xaxis()
#plt.xlim(max(limits),min(limits))
plt.legend()
#plt.gca().invert_yaxis()
#plt.savefig('Results3/plots/windmill_error.png') 
plt.show()
# Out:
# [[0.02775977526610477], [0.027780150542547295], [0.027816755255393837], [0.027859386476300325], [0.02792077970914255], [0.027989530937329993], [0.028058645779326864], [0.02814070462721942], [0.028198532607623783], [0.028296609491003755], [0.028446207283666303], [0.02858023787084512], [0.028767238520960803], [0.029018812590285513], [0.029299427220722374], [0.02971396394863545], [0.03010909745276592], [0.03075051374539873], [0.031591649919160594], [0.032741921390570264], [0.0344720317217703], [0.037025889833078536], [0.04073111493226099]]
# ...

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['font.size'] = 20
print(data[1])
data = []
print(diff[0])

for i in diff:
        data.append(i[2])
print(data[0])
print(data[1])

limits = [120,115,110,105,100,95,90,85,80,75,70,65,60,55,50,45,40,35,30,25,20,15,10]

a = [x[0] for x in data[0]]
b = [x[0] for x in data[1]]
c = [x[0] for x in data[2]]
d = [x[0] for x in data[3]]
e = [x[0] for x in data[4]]
f = [x[0] for x in data[5]]

#print(a[::-1])

plt.plot(limits, a, "-o", label="divide 3")
#plt.gca().invert_xaxis()
plt.plot(limits, b, "-o", label="divide 4")
#plt.gca().invert_xaxis()
plt.plot(limits, c, "-o", label="divide 5")
#plt.gca().invert_xaxis()
plt.plot(limits, d, "-o", label="hybrid (div 3)")

plt.plot(limits, e, "-o", label="Base Line")

plt.plot(limits, f, "-o", label="opt")
#plt.gca().invert_xaxis()
#plt.xlim(max(limits),min(limits))
plt.legend()
#plt.gca().invert_yaxis()
#plt.savefig('Results3/plots/windmill_error.png') 
plt.show()
# Out:
# [[0.42459682629157014], [0.42163595757823247], [0.42163595757823247], [0.41972842471250454], [0.4171380567013017], [0.4120667655896789], [0.3957494533985742], [0.3739004313377209], [0.462234828557967], [0.5281186233890687], [0.5293305477479666], [0.5248270201056062], [0.5195432497227828], [0.5195432497227828], [0.5193954525072378], [0.518458568678461], [0.5104871027207311], [0.5020300198978236], [0.5030374015483626], [0.5019595689423493], [0.5019245707074148], [0.4998200822469931], [0.4986198483261096]]
# ...

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['font.size'] = 20
print(data[1])
data = []
print(diff[0])

for i in diff:
        data.append(i[3])
print(data[0])
print(data[1])

limits = [120,115,110,105,100,95,90,85,80,75,70,65,60,55,50,45,40,35,30,25,20,15,10]

a = [x[0] for x in data[0]]
b = [x[0] for x in data[1]]
c = [x[0] for x in data[2]]
d = [x[0] for x in data[3]]
e = [x[0] for x in data[4]]
f = [x[0] for x in data[5]]

#print(a[::-1])

plt.plot(limits, a, "-o", label="divide 3")
#plt.gca().invert_xaxis()
plt.plot(limits, b, "-o", label="divide 4")
#plt.gca().invert_xaxis()
plt.plot(limits, c, "-o", label="divide 5")
#plt.gca().invert_xaxis()
plt.plot(limits, d, "-o", label="hybrid (div 3)")

plt.plot(limits, e, "-o", label="Base Line")

plt.plot(limits, f, "-o", label="opt")
#plt.gca().invert_xaxis()
#plt.xlim(max(limits),min(limits))
plt.legend()
#plt.gca().invert_yaxis()
#plt.savefig('Results3/plots/windmill_error.png') 
plt.show()
# Out:
# [[0.004931889911197174], [0.004833402560312215], [0.004833402560312215], [0.004833402560312215], [0.004816198173823012], [0.004712998074889528], [0.004697082153995688], [0.0046844192645163225], [0.004506112062355132], [0.004510840360779018], [0.004513359415441102], [0.004527520074572014], [0.004525752377415246], [0.0045883318213191405], [0.004545800344810827], [0.00455451431933492], [0.004577964195232281], [0.004543830108121832], [0.004691973771888855], [0.004725573982900818], [0.004771091137338144], [0.005237571876256469], [0.005812431024722851]]
# ...
