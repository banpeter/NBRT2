# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
from sklearn.model_selection import train_test_split
import csv

# %%
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples=400,
                n_features=3,
                centers=3,
                cluster_std=1,
                shuffle=True,
                random_state=2)



with open("DataSets/blob_att_small.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow(["att1","att2","att3"])
    #writer.writerow(["att1","att2"])
    for row in X:

        writer.writerow(row)


with open("DataSets/blob_label_small.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    for row in y:
        writer.writerow([row])


        
plt.scatter(X[:,0],X[:,1],marker='o',c='blue',s=5)
plt.grid()
plt.show()

# %%
#size: square meter math.sqrt(i+j/10)*7+ 0.2*i)*1000000
#distance from the center 1000/distance +10   dinstance 100-5000 meter
#government support yes = 0-10 million
#local average salaray(HUF) 2-8


X_training = []
y_training = []

header = ["size","distance","support","salary"]

for i in range(10000):
    
    price = 0
    
    size = random.randint(0,99)+random.randint(0,10)/10
    distance = random.randint(30,100)

    support = random.randint(0,10)
    salary = random.randint(3,8)

    price += ((math.sqrt(size)*10+0.3*(size/10)))
    price += (1000/distance + 5)

    price += support
    price += salary**3
    

    X_training.append([size,distance,support,salary])
    y_training.append([price])
    
    
print(len(X_training))
print(len(y_training))    
    


with open("DataSets/house_att.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow(header)
    for row in X_training:

        writer.writerow(row)



with open("DataSets/house_price.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    #writer.writerow(header)
    for row in y_training:

        writer.writerow(row)
# Out:
# 10000
# 10000

# %%
#import iris_dataset

with open("DataSets/iris.csv","r") as file:
    r = csv.reader(file)
    for row in r:
        print(row)
# Out:
# ['sepal.length', 'sepal.width', 'petal.length', 'petal.width', 'variety']
# ['5.1', '3.5', '1.4', '.2', 'Setosa']
# ['4.9', '3', '1.4', '.2', 'Setosa']
# ['4.7', '3.2', '1.3', '.2', 'Setosa']
# ['4.6', '3.1', '1.5', '.2', 'Setosa']
# ['5', '3.6', '1.4', '.2', 'Setosa']
# ['5.4', '3.9', '1.7', '.4', 'Setosa']
# ['4.6', '3.4', '1.4', '.3', 'Setosa']
# ['5', '3.4', '1.5', '.2', 'Setosa']
# ['4.4', '2.9', '1.4', '.2', 'Setosa']
# ['4.9', '3.1', '1.5', '.1', 'Setosa']
# ['5.4', '3.7', '1.5', '.2', 'Setosa']
# ['4.8', '3.4', '1.6', '.2', 'Setosa']
# ['4.8', '3', '1.4', '.1', 'Setosa']
# ['4.3', '3', '1.1', '.1', 'Setosa']
# ['5.8', '4', '1.2', '.2', 'Setosa']
# ['5.7', '4.4', '1.5', '.4', 'Setosa']
# ['5.4', '3.9', '1.3', '.4', 'Setosa']
# ['5.1', '3.5', '1.4', '.3', 'Setosa']
# ['5.7', '3.8', '1.7', '.3', 'Setosa']
# ['5.1', '3.8', '1.5', '.3', 'Setosa']
# ['5.4', '3.4', '1.7', '.2', 'Setosa']
# ['5.1', '3.7', '1.5', '.4', 'Setosa']
# ['4.6', '3.6', '1', '.2', 'Setosa']
# ...

# %%
data = []
with open("DataSets/winequality-white.csv","r") as file:
    r = csv.reader(file)
    for row in r:
        data.append(row[0].split(';'))


writer = csv.writer(open("DataSets/winequality-white_att.csv", 'w',newline=''))
writer.writerow(data[0][:-1])
data.pop(0)
for row in data:

        a = [float(x) for x in row]
        writer.writerow(a)

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=10000, n_features=4, noise=1, random_state=42)
print(X)
with open("DataSets/make_reg_att.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow(["att1","att2","att3","att4"])
    #writer.writerow(["att1","att2"])
    for row in X:

        writer.writerow(row)


with open("DataSets/make_reg_label.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    for row in y:
        writer.writerow([row])
# Out:
# [[ 1.18964265  0.11835007  0.39155118  0.13734132]
#  [-1.50226525  0.56676038  1.06864222 -1.0816511 ]
#  [-1.21780331  0.07456406 -0.37571791  0.95308805]
#  ...
#  [-0.17150916 -0.73673099  0.85205378 -1.17220662]
#  [-0.21329153  0.50049109  0.58589143  0.77150854]
#  [-0.17749188  0.28004534 -2.67456713 -1.75097557]]

# %%
print(y)
# Out:
# [  36.94718717    2.21624536   54.07148409 ... -115.22502827  114.21211958
#  -192.89785466]

# %%
plt.scatter(X[:,0],X[:,1],marker='o',c='blue',s=5)
plt.grid()
plt.show()

# %%
#size: square meter math.sqrt(i+j/10)*7+ 0.2*i)*1000000
#distance from the center 1000/distance +10   dinstance 100-5000 meter
#government support yes = 0-10 million
#local average salaray(HUF) 2-8


X_training = []
y_training = []

header = ["size","salary"]

for i in range(10000):
    
    price = 0
    
    size = random.randint(0,99)+random.randint(0,10)/10
    distance = random.randint(30,100)

    support = random.randint(0,10)
    salary = random.randint(3,8)

    price += ((math.sqrt(size)*10+0.3*(size/10)))



    price += salary**3
    

    X_training.append([size,salary])
    y_training.append([price])
    
    
print(len(X_training))
print(len(y_training))    
    


with open("DataSets/house_att2.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    writer.writerow(header)
    for row in X_training:

        writer.writerow(row)



with open("DataSets/house_price2.csv", 'w',newline='') as f:
    # create the csv writer
    writer = csv.writer(f)

    # write a row to the csv file
    #writer.writerow(header)
    for row in y_training:

        writer.writerow(row)
# Out:
# 10000
# 10000
